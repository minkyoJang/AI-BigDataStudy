# %% [markdown]
# # Naturl Language Processing
# - AI 이야기+ 자연어처리 이야기 기반되야함

# %% [markdown]
# ### 포트폴리오
# - 이 친구가 얼마나 개발 능력이 있느냐가 관건.
# - 실습과제를 더 발전시킬 수 있으면 좋아요.
#     - Toy problem 가지고, 트위터의 50만건 분석하여 어느 지역에 감성분석했다.
#     - 대화할때 실시간으로 이 사람의 감성을 보여주는 걸 해보았다.
#     - 일단 코드 분석 여러번해보고, 따라하는것도 쉽지 않아
#         - 분석을 하려면 코드+논문으로 이해+파워포인트로 가시화+ 오픈소스 다운로드 받아 돌려보고 실험결과 분석+ 개선방안 고민
#         - 워드임배딩, 센티멘털 아날리시스 등의 실습(+ 버트?/에롬드?)
#
# ### CV
# - 택?. html 또는 크롤링 코드처럼 문서편집을 하는데 구인 환경의 문서 편집기
# - 논문은 캐릭터 베이스된 것 사용
# - 내용을 GIT에 올려두고 자신을 소개할때 사용하기

# %% [markdown]
# # 인공지능==================================
# - 정의) 현재는 인간이 컴퓨ㅓ보다 더 잘하는 것을 컴퓨터가 할 수 있도록 하는 연구
# - AI 시스템의 특징)
#     - 자율성
#     - 자율성: 로봇 청소기, 자율 자동차
#     - 맞춤형 : 이전까지는 획욀화된 시스템이었어
#     - 개인화된 시스템 : 맞춤형이 모든 사람들 각각에게 해당된다면 개인화된 것.
#     - 예측
#     - 학습
#     - 적응성
#     - 유연성
#
# - 연구분야
#     - 게임
#     - 기계학습★
#     - 자연어처리★
#     - 인지컴퓨팅, 로보틱스, 감성처리, 영상인식, 인간컴퓨터상호작용, 지식 획득 및 추론★, 계획
#
# - AI Bottleneck
#     - 날리지 레프리젠테이션/프레젠테이션
#     - AI가 사람처럼 작동하게 만들기 위해서 필요한 '지식'을 어떻게 축적해야하나요
#
# #### AI 역량
# - 문제해결력
# - 컴퓨팅사고력
# - 세계관
# - 전문성
# - 창의력
# - 도전정신
# - 협업력
# - 관계능력
#
# #### 머신러닝
# - 퍼포먼스 향상(=learning)
#
# #### 머신러닝 Task
# - Discrimination Task
#     - classification
#     - clustering
# - Generation Task
#     - Gan등을 이용하여, 삼다수 입력에 대해 삼다수 그림 그리는 식
#
# #### 머신러닝 3종류
# - 지도학습
# - 비지도학습
# - 강화 학습
#
# #### 부가적으로 공부하면 좋을 분야
# - 사람에 대한 학문
#     - 철학
#     - 의학
#     - 심리학
#
# #### NLP Basic
# - NLP: 컴퓨터가 사람이 사용하는 자연적인 언어를 이해하거나 생성하도록 하는 모든 것
# - 1. NLU_Natural Language Understanding_(언더스탠딩) 파트
#     - sementic representation 형태로 converting 하는 것.
#     - 이 파트는 복잡하기 때문에 일반적으로는 단계를 나눠서 진행
#         <>딥러닝은 일반적으로 한번에 끝내곤 함
#     - 핵심: 말하고자 하는 바를 이해하기
#
#
# - 2. NLG_Natural language Generate_(리스폰스) 파트
#
#
# #### General steps in NLP
# - Lexical analysis(part of speech tagging)
#         -1. 품사 정보 알아내고 결정하기
#             - 단어마다 품사가 여러개일 수 있으니 고려하기. 관사/정관사? 명사/복합명사 등등
# - Syntactic analaysis(parsing)
#         - (1)수형도 (parse-tree)를 통해 문장의 구조를 분석하기
#         - (2) Dependency parsing:Dependency 관계로 문장 구조 파악
# - Semetic analysis
#     - 아름 다운 배를 샀다. 어떤배?
# - Inference
#     - 추론: 이러니까 이게 어떻하겠네. (이 과정으로 knowlege 축적)
# - Discourse analysis
#
# #### NLP hard?
# - Language is ambiguous ('중의성)'
# - 하나의 ambiguous한 것에 대해 실패하면 전체가 무너지기에 작업이 어려움
#     - "At last, a computer that understatnds you like your mother"
#         - 1. 어머니가 당신을 이해하는 것처럼 당신을 이해하는 컴퓨터
#         - 2. 당신이 당신의 어머니를 좋아한다는 사실을 컴퓨터가 이해한다.
#         - 3. 당신이 컴퓨터를 ~.
#         - 즉 like를 동사/형용사 중 어떤 것으로 해석하느냐에 따라 달라짐
#     - 2. structural ambiguity
#
#
# #### Major issue for NLP
#     - 기호주의 (symbolic한 approach)
#         - 이러한 규칙을 knowledge라고 이야기하기도 해요
#     - 경험주의 (empirical approch)
#
# #### NLP applications
# - Text Categorization
#     - 센티멘탈, 트위터 고객들이 가진 감성 분석
#     - 스팸메일 시스템, 민원 분류
# - Spelling Grammar Corrections
#     - 음성인식 기술이 발전하면서 각광을 받고 있는 중
# - INformation Extraction
# - Speech Recognition
# - Information Retrieval
# - Summarization
#     - extractive
#         - 1000개의 문서를 10프로로 줄이겠다. 이 중에서 100개의 중요 문장을 만들겠다
#     - abstractive
#         - 실제 문서를 이해하고 새로운 용어로 작성해내는 기법.
#         - 현재 needs가 높고 연구가 많이 진행되며, 가장 많이 사용되는게 RNN model
# - Machine Translation
# - Question and Answering
#     - 정보검색은 별로 친절하지 않은 시스템이라 잘 안 쓸거라고 교수님 예언()
#     - Dialog System

# %% [markdown]
# #### 교수님 대답
# (1)
# - 질문에 대한 표현은 워드 리프리젠트가  맞는 식. 어떻게 이걸 입력 줄거냐 해서 변환하고, 그 이후에 이 입력을 사용
# - NLP 모델을 만들기 위한 준비작업을 하고, 텍스트 입력에 대해서 백터화 하고 구문분석/감성분석을 하는 식
# - 어플리케이션 배운 것들 단계할때 입력으로 들어가는게 DENSE-VECTOR로 바꾼게 입력으로 들어감.
#     - cnn, RNN을 이용하여 워드 임배딩이 가능함. 그러나 이거로만 가능한건 아니고, 임배딩을 위한 수학적인 방법이 많긴함
#     - 그 중에 성능이 좋은게 버트나 엑셀넷이다.
#     - 그거로 숫자 표현이 되면 다음에 감정 분석을 할떄 CNN 분석을 통해 CNN 감성분석을 하고, 데이터를 이용하여 다음에 나올 단어를 예측하기 위해 RNN을 이용하기도 함.
#
#
#
# (2)
# - 딥러닝이 전부가 아니라 한계가 있고
# - 지식이 규칙이든 언어지식이든 워드 날리지이든 결합이 되면 딥러닝 모델을 향상할 수 있음
# - 그래서 교수님 랩실에서는 하이브리드안 어프로치를 고민하고 계심.(앙상블 말고, 어떻게 워드 나리지가 딥러닝 모델 만들 것인지)
# - 그래서 GCN이라는 모델이 있는데, 이건 그래피컬 컨볼루션 네트워크
#     - 그래프 형태로 날리지를 표현하고 그것을 CNN에 임배딩해서 만드는 모델.
#     - 이 모델에 대한 연구가 많이 되고 있음.
#     - 그러나 이 그래프는 심볼릭한 어프로치인지라, 어떻게 딥러닝 베이스와 결합할지 . 임플릭과 연계할지. 이런게 연구 많이 될 것이라 보심

# %% [markdown]
# # 에러 줄이기
# 1. 확률 계산
# - 각 단어별로
#
# #### 스펠링 에러
# - 어떤 단어가 딜리젼 되어 생길 수 있고 에드가 되어 생길 수 있음.
#
#
# #### POS Tagging
# - 형태소 분석?
#     - 나는 이라는 단어가 들어오면 싹이 나는 걸 수도 있고, 사람이 난다라는 것일 수도 있고, 나와너 할때 대명사 플러스 조사 이 수 있어
#     - 형태소 분석은 어떤 결합으로 분석 될 수 있는지 다 찾는것. 이게 morphological analysis
#     - part of speech tagging 이후에 진행. (@)
#             - 규칙 기반/ 통계 기반 모델
#                 - 통계 기반 모델: 각각 형태소 중에 하나만이 올바른 경로임. 가장 확률이 높게 만들어지는 것을 수학적 모델로 찾아내기
#                     - 딥러닝모델: 문장 입력에 대해 각각 형태소 분석 결과가 나오고 그걸 seq2seq로 만드는 것
#                             <- 교수님 연구실 자료를 사용하면 형태소 분석을 데모 형태로 해볼 수 있음

# %% [markdown]
# ### 구문분석
# #### NEP (Named Entity Recognition)
# -예) 애플
#     - 사람? 과일? 회사? 분석하는 부분
#
# - 구분 분석 2방식
#     - parse structural parsing
#     - dependency parsing
#
# #### PCFG : Probabilistic Context-Free Grammars (PCFGs)
# - 어떠한 파스트리가 더 좋은지 찾아서 중의성을 해결하는데 사용됨
#
#
# ## sementic analysis
# - 구문 분석 이후에 진행
# - 핵심2가지
#     - 워드 샌스
#         - 예)어떤 배인지 찾는것
#     - 시맨틱 워 레이블링 Semantic Role Labeling
#         - 네임드엔티티는 장소/사람인지 찾는거였다면 이것은 실제로 어떤 역할을 하는지. 의미적으로 어떠한 역할 role을 하는지 보는 것
#             - 역할 정보 찾아내기
#                 - tajan kissed jane.
#                     <> jane was kissed by tajan. (여기서 주어는 jane이나 역할로 보면 object임. 이런거 찾아내기)

# %% [markdown]
# ## Discouse Analysis
# - Reference resolution_대용어 해결_문장에서 지칭어 찾기
#     - U: i would like to open a fixed deposit account
#     - S: For what accont?
#     - U: Make it for 8000 dollars.
#     - ** 여기에서 it이 의미하는거 위로 올라가 찾아보기
# - Speech Act Identification_화행분석)
#     - 이 말을 한 문장의 실제 의도가 무엇인지 찾아내기
